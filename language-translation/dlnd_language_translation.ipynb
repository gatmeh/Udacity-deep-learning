# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    # split the incomping texts by sentences
    source_text = source_text.split('\n')
    target_text = target_text.split('\n')
    
    # do some cleanup on text
    import re
    # remove '\n' char
    for i,sentense in enumerate(source_text):
        source_text[i] = re.sub(r'\n', '', source_text[i])
        
    # remove '\n' char
    # add end of sentence work to end of target text)
    for i,sentense in enumerate(target_text):
        target_text[i] = re.sub(r'\n', '', target_text[i])
        target_text[i] += ' <EOS>'
    
    # create ids lists
    source_id_text = [[source_vocab_to_int[word] for word in sentense.split()] for sentense in source_text]
    target_id_text = [[target_vocab_to_int[word] for word in sentense.split()] for sentense in target_text]
    
    return source_id_text, target_id_text
          

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.1.0
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/ipykernel_launcher.py:15: UserWarning: No GPU found. Please use a GPU to train your neural network.
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    input_text = tf.placeholder(shape=([None, None]), dtype=tf.int32, name='input')
    target_text = tf.placeholder(shape=([None, None]), dtype=tf.int32, name='targets')
    learning_rate = tf.placeholder(shape=None, dtype=tf.float32, name='learning_rate')
    keep_prob = tf.placeholder(shape=None, dtype=tf.float32, name='keep_prob')
    target_sequence_length = tf.placeholder(shape=([None]), dtype=tf.int32, name='target_sequence_length')
    max_target_length = tf.reduce_max(target_sequence_length, name='max_target_len')
    source_sequence_length  = tf.placeholder(shape=([None]), dtype=tf.int32, name='source_sequence_length')
    
    return input_text, target_text, learning_rate, keep_prob, target_sequence_length, max_target_length, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    # TODO: Implement Function
    ending = tf.strided_slice(target_data, [0, 0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)
    
    return dec_input

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    # TODO: Implement Function
    # Encoder embedding
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)

    # RNN cell
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        enc_cell = tf.contrib.rnn.DropoutWrapper(enc_cell, keep_prob)
        return enc_cell

    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    # TODO: Implement Function
    
    # Helper for the training process. Used by BasicDecoder to read inputs.
    training_helper = tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                        sequence_length=target_sequence_length,
                                                        time_major=False)


    # Basic decoder
    training_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       training_helper,
                                                       encoder_state,
                                                       output_layer) 

    # Perform dynamic decoding using the decoder
    training_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                                   impute_finished=True,
                                                                   maximum_iterations=max_summary_length)
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # TODO: Implement Function
    # Reuses the same parameters trained by the training process
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')

    # Helper for the inference process.
    inference_helper = tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                            start_tokens,
                                                            end_of_sequence_id)

    # Basic decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    inference_helper,
                                                    encoder_state,
                                                    output_layer)

    # Perform dynamic decoding using the decoder
    inference_decoder_output, _ = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                        impute_finished=True,
                                                        maximum_iterations=max_target_sequence_length)
    
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
    # 1. Decoder Embedding
    target_vocab_size = len(target_vocab_to_int)
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)

    # 2. Construct the decoder cell
    def make_cell(rnn_size):
        dec_cell = tf.contrib.rnn.LSTMCell(rnn_size,
                                           initializer=tf.random_uniform_initializer(-0.1, 0.1, seed=2))
        
        dec_cell = tf.contrib.rnn.DropoutWrapper(dec_cell, keep_prob)
        
        return dec_cell

    dec_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
     
    # 3. Dense layer to translate the decoder's output at each time 
    # step into a choice from the target vocabulary
    output_layer = Dense(target_vocab_size,
                         kernel_initializer = tf.truncated_normal_initializer(mean = 0.0, stddev=0.1))


    # 4. Set up a training decoder and an inference decoder
    # Training Decoder
    with tf.variable_scope("decode"):
        training_decoder_output = decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                             target_sequence_length, max_target_sequence_length, 
                             output_layer, keep_prob)

    # 5. Inference Decoder
    
    with tf.variable_scope("decode", reuse=True):
        inference_decoder_output = decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, 
                                target_vocab_to_int['<GO>'],
                                target_vocab_to_int['<EOS>'], max_target_sequence_length,
                                target_vocab_size, output_layer, batch_size, keep_prob)
    
    return training_decoder_output, inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# tests.test_decoding_layer(decoding_layer)
# Out:
# "\nDON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE\n"

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # TODO: Implement Function
   
    _, enc_state = encoding_layer(input_data, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   enc_embedding_size)
    
    # Prepare the target sequences we'll feed to the decoder in training mode
    dec_input = process_decoder_input(target_data, target_vocab_to_int, batch_size)
    
    # Pass encoder state and decoder inputs to the decoders
    training_decoder_output, inference_decoder_output = decoding_layer(dec_input, enc_state,
                   target_sequence_length, max_target_sentence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, dec_embedding_size)
    
   
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-152-5e4d1d3ee4ac> in <module>()
#      45 DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
#      46 """
# ---> 47 tests.test_seq2seq_model(seq2seq_model)
#
# /home/gus/Documents/deep_learning_nanodegree/deep-learning/language-translation/problem_unittests.py in test_seq2seq_model(seq2seq_model)
#     254
#     255         assert train_decoder_output.rnn_output.get_shape().as_list() == [batch_size, None, vocab_size], \
# --> 256             'Wrong shape returned.  Found {}'.format(train_decoder_output.get_shape())
#     257         assert infer_logits_output.sample_id.get_shape().as_list() == [batch_size, None], \
#     258              'Wrong shape returned.  Found {}'.format(infer_logits_output.sample_id.get_shape())
#
# AttributeError: 'BasicDecoderOutput' object has no attribute 'get_shape'

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 10
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 100
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 300
decoding_embedding_size = 300
# Learning Rate
learning_rate = 0.01
# Dropout Keep Probability
keep_probability = 0.5
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2866, Validation Accuracy: 0.3718, Loss: 3.4445
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.3551, Validation Accuracy: 0.4144, Loss: 2.8092
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3984, Validation Accuracy: 0.4538, Loss: 2.6031
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.4266, Validation Accuracy: 0.4691, Loss: 2.4124
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.4637, Validation Accuracy: 0.5188, Loss: 2.3538
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4874, Validation Accuracy: 0.5121, Loss: 2.0357
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.5323, Loss: 1.8821
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5082, Loss: 1.6434
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4672, Validation Accuracy: 0.5156, Loss: 1.5552
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4953, Validation Accuracy: 0.5202, Loss: 1.3988
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4895, Validation Accuracy: 0.5014, Loss: 1.2335
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4836, Validation Accuracy: 0.5213, Loss: 1.2295
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.5312, Validation Accuracy: 0.5217, Loss: 1.0597
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4692, Validation Accuracy: 0.5302, Loss: 1.1364
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.5856, Validation Accuracy: 0.5586, Loss: 0.9589
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.5728, Loss: 0.9427
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.5539, Validation Accuracy: 0.5692, Loss: 0.9626
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.5832, Validation Accuracy: 0.5831, Loss: 0.9043
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.6141, Validation Accuracy: 0.6072, Loss: 0.8510
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.5781, Validation Accuracy: 0.5692, Loss: 0.8415
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.5774, Loss: 0.8411
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.5876, Validation Accuracy: 0.6101, Loss: 0.7894
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.6105, Validation Accuracy: 0.5856, Loss: 0.7368
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.6277, Validation Accuracy: 0.5781, Loss: 0.7332
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.6239, Validation Accuracy: 0.5891, Loss: 0.6741
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.6417, Validation Accuracy: 0.6058, Loss: 0.6698
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.6027, Validation Accuracy: 0.6062, Loss: 0.7390
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.6223, Validation Accuracy: 0.6161, Loss: 0.7110
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.6254, Validation Accuracy: 0.6115, Loss: 0.7003
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.6464, Validation Accuracy: 0.6342, Loss: 0.6525
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.6129, Validation Accuracy: 0.6264, Loss: 0.6740
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.6746, Validation Accuracy: 0.6456, Loss: 0.6202
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.6719, Validation Accuracy: 0.6151, Loss: 0.5986
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.6813, Validation Accuracy: 0.6403, Loss: 0.6003
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.6621, Validation Accuracy: 0.6417, Loss: 0.6227
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.6488, Validation Accuracy: 0.6871, Loss: 0.5775
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.7240, Validation Accuracy: 0.6932, Loss: 0.5437
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.7078, Validation Accuracy: 0.6793, Loss: 0.5304
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.6777, Validation Accuracy: 0.7070, Loss: 0.5492
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.7141, Validation Accuracy: 0.6832, Loss: 0.5413
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.6842, Validation Accuracy: 0.7077, Loss: 0.5477
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.7449, Validation Accuracy: 0.7255, Loss: 0.4772
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.7109, Validation Accuracy: 0.7042, Loss: 0.4985
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.7438, Validation Accuracy: 0.7209, Loss: 0.5281
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.7328, Validation Accuracy: 0.6957, Loss: 0.4629
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.7332, Validation Accuracy: 0.7315, Loss: 0.4954
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.7175, Validation Accuracy: 0.7184, Loss: 0.4888
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.7393, Validation Accuracy: 0.7113, Loss: 0.4577
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.7066, Validation Accuracy: 0.7209, Loss: 0.4547
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.7441, Validation Accuracy: 0.7283, Loss: 0.4283
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.7461, Validation Accuracy: 0.7486, Loss: 0.4095
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.7850, Validation Accuracy: 0.7582, Loss: 0.3722
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.7383, Validation Accuracy: 0.7106, Loss: 0.4268
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.7676, Validation Accuracy: 0.7457, Loss: 0.3673
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.7160, Validation Accuracy: 0.7369, Loss: 0.4044
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.7523, Validation Accuracy: 0.7408, Loss: 0.3728
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.7648, Validation Accuracy: 0.7521, Loss: 0.4021
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.7842, Validation Accuracy: 0.7717, Loss: 0.3391
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.7101, Validation Accuracy: 0.7386, Loss: 0.3935
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.7943, Validation Accuracy: 0.7667, Loss: 0.3524
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.7887, Validation Accuracy: 0.7915, Loss: 0.3610
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.8152, Validation Accuracy: 0.7816, Loss: 0.3354
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.7949, Validation Accuracy: 0.7731, Loss: 0.3477
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.7660, Validation Accuracy: 0.7749, Loss: 0.3420
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.7832, Validation Accuracy: 0.7621, Loss: 0.3512
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.7945, Validation Accuracy: 0.7695, Loss: 0.3548
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.8011, Validation Accuracy: 0.7848, Loss: 0.3102
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.7731, Validation Accuracy: 0.7905, Loss: 0.3054
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.8508, Validation Accuracy: 0.7919, Loss: 0.3198
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.8074, Validation Accuracy: 0.7951, Loss: 0.3001
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.8043, Validation Accuracy: 0.7919, Loss: 0.3069
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.7899, Validation Accuracy: 0.7919, Loss: 0.3190
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.8156, Validation Accuracy: 0.7894, Loss: 0.3044
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.8199, Validation Accuracy: 0.7930, Loss: 0.2780
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.8195, Validation Accuracy: 0.7994, Loss: 0.2829
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.8094, Validation Accuracy: 0.8146, Loss: 0.3106
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.7883, Validation Accuracy: 0.8079, Loss: 0.2628
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.8063, Validation Accuracy: 0.8072, Loss: 0.3032
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.7371, Validation Accuracy: 0.8054, Loss: 0.2885
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.8148, Validation Accuracy: 0.7990, Loss: 0.2717
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.8103, Validation Accuracy: 0.8050, Loss: 0.2340
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.7949, Validation Accuracy: 0.7994, Loss: 0.2599
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.8352, Validation Accuracy: 0.8036, Loss: 0.2605
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.8402, Validation Accuracy: 0.8175, Loss: 0.2400
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.8002, Validation Accuracy: 0.8171, Loss: 0.2724
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.8482, Validation Accuracy: 0.8196, Loss: 0.2532
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.7615, Validation Accuracy: 0.8324, Loss: 0.2571
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8292, Loss: 0.2323
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.8378, Validation Accuracy: 0.8221, Loss: 0.2140
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.8570, Validation Accuracy: 0.8434, Loss: 0.2453
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.8344, Validation Accuracy: 0.8058, Loss: 0.2159
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.8418, Validation Accuracy: 0.8295, Loss: 0.2216
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.8617, Validation Accuracy: 0.8182, Loss: 0.2125
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.8258, Validation Accuracy: 0.7947, Loss: 0.2084
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.8504, Validation Accuracy: 0.8398, Loss: 0.2047
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.8553, Validation Accuracy: 0.8182, Loss: 0.1962
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8420, Loss: 0.2257
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.8121, Validation Accuracy: 0.8203, Loss: 0.2128
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.8372, Validation Accuracy: 0.8601, Loss: 0.2212
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.8601, Validation Accuracy: 0.8327, Loss: 0.1812
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.8676, Validation Accuracy: 0.8445, Loss: 0.1904
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.8645, Validation Accuracy: 0.8416, Loss: 0.1742
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.8570, Validation Accuracy: 0.8423, Loss: 0.1975
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.8799, Validation Accuracy: 0.8278, Loss: 0.2005
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.8316, Validation Accuracy: 0.8246, Loss: 0.1736
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8473, Loss: 0.1658
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.8477, Validation Accuracy: 0.8477, Loss: 0.1730
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.8499, Validation Accuracy: 0.8303, Loss: 0.1703
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8416, Loss: 0.1413
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.8562, Validation Accuracy: 0.8562, Loss: 0.1666
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8409, Loss: 0.1556
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.8793, Validation Accuracy: 0.8597, Loss: 0.1579
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.8940, Validation Accuracy: 0.8406, Loss: 0.1442
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.8072, Validation Accuracy: 0.8356, Loss: 0.1698
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8544, Loss: 0.1409
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8452, Loss: 0.1778
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.8730, Validation Accuracy: 0.8530, Loss: 0.1544
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.8699, Validation Accuracy: 0.8501, Loss: 0.1268
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.8656, Validation Accuracy: 0.8672, Loss: 0.1752
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8494, Loss: 0.1345
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8406, Loss: 0.1433
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.8903, Validation Accuracy: 0.8374, Loss: 0.1525
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.9008, Validation Accuracy: 0.8654, Loss: 0.1312
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.8699, Validation Accuracy: 0.8643, Loss: 0.1399
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8754, Loss: 0.1376
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.8761, Loss: 0.1315
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.8691, Validation Accuracy: 0.8604, Loss: 0.1542
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.8720, Validation Accuracy: 0.8686, Loss: 0.1527
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.8882, Validation Accuracy: 0.8686, Loss: 0.1354
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.8958, Validation Accuracy: 0.8800, Loss: 0.1394
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.8863, Validation Accuracy: 0.8714, Loss: 0.1429
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.8835, Validation Accuracy: 0.8718, Loss: 0.1234
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.8854, Validation Accuracy: 0.8775, Loss: 0.1052
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.8379, Validation Accuracy: 0.8828, Loss: 0.1490
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.8598, Validation Accuracy: 0.8643, Loss: 0.1337
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.8594, Validation Accuracy: 0.8619, Loss: 0.1613
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.9206, Validation Accuracy: 0.8775, Loss: 0.1227
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.8867, Validation Accuracy: 0.8537, Loss: 0.1178
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8725, Loss: 0.1418
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.8629, Validation Accuracy: 0.8619, Loss: 0.1397
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.9050, Validation Accuracy: 0.8647, Loss: 0.1361
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.8469, Validation Accuracy: 0.8580, Loss: 0.1500
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.8762, Validation Accuracy: 0.8782, Loss: 0.1170
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8615, Loss: 0.1242
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.8672, Loss: 0.1194
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.8566, Validation Accuracy: 0.8782, Loss: 0.1273
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.8580, Loss: 0.1339
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.8705, Validation Accuracy: 0.8732, Loss: 0.1347
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8718, Loss: 0.1096
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8601, Loss: 0.1076
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.8613, Validation Accuracy: 0.8562, Loss: 0.1385
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.8664, Validation Accuracy: 0.8683, Loss: 0.1245
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.8719, Validation Accuracy: 0.8949, Loss: 0.1368
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.8964, Validation Accuracy: 0.8714, Loss: 0.1318
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8757, Loss: 0.1360
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8675, Loss: 0.1260
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8796, Loss: 0.1041
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.8903, Loss: 0.1194
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.8945, Loss: 0.0993
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8711, Loss: 0.1280
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.8821, Loss: 0.0993
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.8609, Validation Accuracy: 0.8558, Loss: 0.1098
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.8754, Validation Accuracy: 0.8633, Loss: 0.1084
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.8475, Validation Accuracy: 0.8601, Loss: 0.1380
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.9152, Validation Accuracy: 0.8743, Loss: 0.1014
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.8491, Validation Accuracy: 0.8722, Loss: 0.1248
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.8966, Validation Accuracy: 0.8651, Loss: 0.1190
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.8877, Validation Accuracy: 0.8665, Loss: 0.1350
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8761, Loss: 0.1037
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.8739, Loss: 0.1026
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.8828, Validation Accuracy: 0.8686, Loss: 0.1200
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.8852, Validation Accuracy: 0.8896, Loss: 0.1079
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8913, Loss: 0.1059
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.8896, Validation Accuracy: 0.8771, Loss: 0.1096
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.8839, Validation Accuracy: 0.8860, Loss: 0.0984
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8860, Loss: 0.1089
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.8693, Loss: 0.0949
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.8878, Loss: 0.1014
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.8882, Validation Accuracy: 0.8842, Loss: 0.1137
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.8896, Loss: 0.1182
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.8711, Loss: 0.1042
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.8914, Validation Accuracy: 0.8903, Loss: 0.0907
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8793, Loss: 0.1240
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8821, Loss: 0.1022
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.8621, Validation Accuracy: 0.8984, Loss: 0.1327
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.8473, Validation Accuracy: 0.8693, Loss: 0.0998
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.8988, Loss: 0.1061
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.8876, Validation Accuracy: 0.8789, Loss: 0.0881
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8891, Validation Accuracy: 0.8853, Loss: 0.1019
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.8761, Loss: 0.1046
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.8953, Validation Accuracy: 0.8860, Loss: 0.0846
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.8709, Validation Accuracy: 0.9016, Loss: 0.1456
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.9048, Validation Accuracy: 0.8938, Loss: 0.1085
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.8569, Validation Accuracy: 0.8668, Loss: 0.1054
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.8960, Loss: 0.1114
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8686, Loss: 0.1016
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.8860, Loss: 0.1209
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.8862, Validation Accuracy: 0.8832, Loss: 0.1075
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.8816, Validation Accuracy: 0.8526, Loss: 0.1083
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.9121, Validation Accuracy: 0.8789, Loss: 0.0888
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.8377, Loss: 0.0930
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.8697, Loss: 0.0981
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.8955, Validation Accuracy: 0.8803, Loss: 0.0968
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.8892, Loss: 0.1027
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.8844, Validation Accuracy: 0.8888, Loss: 0.1024
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.8758, Validation Accuracy: 0.8707, Loss: 0.1153
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8832, Loss: 0.1029
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.9109, Loss: 0.0963
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9055, Loss: 0.0877
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8942, Loss: 0.1059
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.9017, Validation Accuracy: 0.8910, Loss: 0.1096
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.9090, Validation Accuracy: 0.8668, Loss: 0.0913
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.8935, Loss: 0.1004
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.8757, Loss: 0.0970
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.8910, Validation Accuracy: 0.8700, Loss: 0.0985
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.9074, Validation Accuracy: 0.8846, Loss: 0.0800
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.9109, Loss: 0.0828
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.8875, Validation Accuracy: 0.8857, Loss: 0.0866
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.9043, Validation Accuracy: 0.8860, Loss: 0.0994
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8700, Loss: 0.0789
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.8939, Validation Accuracy: 0.8956, Loss: 0.1064
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.8969, Validation Accuracy: 0.8658, Loss: 0.0866
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.8965, Validation Accuracy: 0.8849, Loss: 0.1069
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8920, Loss: 0.0862
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.9277, Validation Accuracy: 0.8849, Loss: 0.0770
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8871, Loss: 0.1076
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.8814, Loss: 0.0749
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9165, Validation Accuracy: 0.8626, Loss: 0.0895
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.9044, Validation Accuracy: 0.8793, Loss: 0.0923
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9191, Validation Accuracy: 0.8825, Loss: 0.0768
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.8786, Loss: 0.0934
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9156, Validation Accuracy: 0.8874, Loss: 0.0787
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.8920, Loss: 0.0859
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8860, Loss: 0.1057
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.9115, Validation Accuracy: 0.8849, Loss: 0.0990
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.8754, Loss: 0.0853
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.8729, Loss: 0.0880
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9410, Validation Accuracy: 0.8683, Loss: 0.0902
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.8835, Loss: 0.0815
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.8928, Loss: 0.0734
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8938, Loss: 0.1011
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.8855, Validation Accuracy: 0.8906, Loss: 0.0981
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.8848, Validation Accuracy: 0.9016, Loss: 0.1078
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.8739, Loss: 0.0860
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.8814, Loss: 0.0937
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9246, Validation Accuracy: 0.8913, Loss: 0.1036
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.8931, Loss: 0.0866
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.8981, Loss: 0.0763
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.8930, Validation Accuracy: 0.9041, Loss: 0.1102
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8714, Loss: 0.0870
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.8789, Loss: 0.0842
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.8970, Loss: 0.0757
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8864, Loss: 0.0958
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.8690, Loss: 0.1030
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.8882, Validation Accuracy: 0.8750, Loss: 0.0966
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9270, Validation Accuracy: 0.9155, Loss: 0.0779
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8846, Loss: 0.0850
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.8672, Validation Accuracy: 0.8835, Loss: 0.1142
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.8601, Loss: 0.0880
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8910, Loss: 0.0934
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.9235, Validation Accuracy: 0.8786, Loss: 0.1017
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.8939, Validation Accuracy: 0.8793, Loss: 0.0848
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.8842, Loss: 0.0897
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8995, Loss: 0.0657
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8967, Loss: 0.0885
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.9048, Loss: 0.0798
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.8879, Validation Accuracy: 0.8860, Loss: 0.0960
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9077, Loss: 0.0825
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.8859, Validation Accuracy: 0.8928, Loss: 0.0871
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9234, Validation Accuracy: 0.8810, Loss: 0.0829
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.8898, Validation Accuracy: 0.8846, Loss: 0.0999
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9222, Validation Accuracy: 0.8977, Loss: 0.0768
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.8865, Validation Accuracy: 0.9062, Loss: 0.1054
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9122, Validation Accuracy: 0.9016, Loss: 0.0954
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.8963, Loss: 0.0956
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9328, Validation Accuracy: 0.8853, Loss: 0.0739
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9052, Loss: 0.0858
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.8969, Validation Accuracy: 0.9091, Loss: 0.0842
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.9034, Loss: 0.0880
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.9066, Loss: 0.0913
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.8949, Loss: 0.1051
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9204, Validation Accuracy: 0.9002, Loss: 0.0727
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9009, Loss: 0.0773
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.8931, Loss: 0.0730
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8881, Loss: 0.0673
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.9055, Loss: 0.0813
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.9109, Validation Accuracy: 0.8764, Loss: 0.0810
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.9116, Loss: 0.0871
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8991, Loss: 0.0733
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9195, Validation Accuracy: 0.9077, Loss: 0.0922
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.8925, Validation Accuracy: 0.9151, Loss: 0.0875
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.8820, Validation Accuracy: 0.9105, Loss: 0.1140
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.8578, Validation Accuracy: 0.8942, Loss: 0.0888
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.9087, Loss: 0.0812
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.8931, Loss: 0.0732
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.9055, Loss: 0.0842
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.8734, Validation Accuracy: 0.8892, Loss: 0.0834
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9254, Validation Accuracy: 0.9031, Loss: 0.0735
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.9016, Loss: 0.1285
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8793, Loss: 0.0853
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.8824, Validation Accuracy: 0.8942, Loss: 0.0913
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.8871, Loss: 0.0938
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.8888, Loss: 0.0733
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9041, Loss: 0.0981
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.9007, Validation Accuracy: 0.9212, Loss: 0.0803
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9137, Validation Accuracy: 0.8995, Loss: 0.0925
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.9102, Validation Accuracy: 0.9009, Loss: 0.0769
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.8977, Validation Accuracy: 0.8714, Loss: 0.0831
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.9252, Validation Accuracy: 0.8771, Loss: 0.0675
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.8757, Loss: 0.0802
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.8810, Loss: 0.0793
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.8941, Validation Accuracy: 0.9183, Loss: 0.0962
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.8779, Validation Accuracy: 0.8952, Loss: 0.0939
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9100, Validation Accuracy: 0.8885, Loss: 0.0775
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.8942, Loss: 0.0821
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.9045, Loss: 0.0728
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.8874, Loss: 0.0865
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9145, Validation Accuracy: 0.8892, Loss: 0.0923
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.8672, Loss: 0.0700
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9141, Validation Accuracy: 0.9031, Loss: 0.0813
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.9160, Validation Accuracy: 0.8853, Loss: 0.0791
# Epoch   3 Batch   10/1077 - Train Accuracy: 0.8993, Validation Accuracy: 0.8974, Loss: 0.0810
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.9199, Validation Accuracy: 0.8952, Loss: 0.0681
# Epoch   3 Batch   30/1077 - Train Accuracy: 0.9027, Validation Accuracy: 0.9094, Loss: 0.0712
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.8807, Loss: 0.0723
# Epoch   3 Batch   50/1077 - Train Accuracy: 0.9273, Validation Accuracy: 0.9102, Loss: 0.0897
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.9263, Validation Accuracy: 0.9023, Loss: 0.0643
# Epoch   3 Batch   70/1077 - Train Accuracy: 0.8906, Validation Accuracy: 0.8952, Loss: 0.0884
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.8988, Validation Accuracy: 0.8867, Loss: 0.0785
# Epoch   3 Batch   90/1077 - Train Accuracy: 0.8938, Validation Accuracy: 0.8960, Loss: 0.0909
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.9070, Validation Accuracy: 0.8977, Loss: 0.0895
# Epoch   3 Batch  110/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.8778, Loss: 0.0698
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9002, Loss: 0.0956
# Epoch   3 Batch  130/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.8846, Loss: 0.0697
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.9165, Validation Accuracy: 0.8960, Loss: 0.0815
# Epoch   3 Batch  150/1077 - Train Accuracy: 0.9252, Validation Accuracy: 0.8928, Loss: 0.0715
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8910, Loss: 0.0820
# Epoch   3 Batch  170/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.8995, Loss: 0.0801
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9212, Loss: 0.0667
# Epoch   3 Batch  190/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9052, Loss: 0.0624
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8984, Loss: 0.0804
# Epoch   3 Batch  210/1077 - Train Accuracy: 0.9092, Validation Accuracy: 0.9265, Loss: 0.0884
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.9174, Validation Accuracy: 0.8746, Loss: 0.0828
# Epoch   3 Batch  230/1077 - Train Accuracy: 0.9167, Validation Accuracy: 0.9027, Loss: 0.0920
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9041, Loss: 0.0792
# Epoch   3 Batch  250/1077 - Train Accuracy: 0.9315, Validation Accuracy: 0.9123, Loss: 0.0691
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.9092, Validation Accuracy: 0.9059, Loss: 0.0572
# Epoch   3 Batch  270/1077 - Train Accuracy: 0.9012, Validation Accuracy: 0.9087, Loss: 0.1003
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.9105, Validation Accuracy: 0.9084, Loss: 0.0817
# Epoch   3 Batch  290/1077 - Train Accuracy: 0.8949, Validation Accuracy: 0.9169, Loss: 0.1087
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.9248, Validation Accuracy: 0.8988, Loss: 0.0742
# Epoch   3 Batch  310/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9052, Loss: 0.0741
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.8945, Loss: 0.1050
# Epoch   3 Batch  330/1077 - Train Accuracy: 0.8859, Validation Accuracy: 0.8977, Loss: 0.0887
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9041, Loss: 0.0786
# Epoch   3 Batch  350/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.8981, Loss: 0.1012
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8849, Loss: 0.0643
# Epoch   3 Batch  370/1077 - Train Accuracy: 0.9487, Validation Accuracy: 0.8938, Loss: 0.0726
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9469, Validation Accuracy: 0.9077, Loss: 0.0565
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-156-8b554ffa681f> in <module>()
#      46                  target_sequence_length: targets_lengths,
#      47                  source_sequence_length: sources_lengths,
# ---> 48                  keep_prob: keep_probability})
#      49
#      50
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     776     try:
#     777       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 778                          run_metadata_ptr)
#     779       if run_metadata:
#     780         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     980     if final_fetches or final_targets:
#     981       results = self._do_run(handle, final_targets, final_fetches,
# --> 982                              feed_dict_string, options, run_metadata)
#     983     else:
#     984       results = []
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1030     if handle is None:
#    1031       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1032                            target_list, options, run_metadata)
#    1033     else:
#    1034       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1037   def _do_call(self, fn, *args):
#    1038     try:
# -> 1039       return fn(*args)
#    1040     except errors.OpError as e:
#    1041       message = compat.as_text(e.message)
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1019         return tf_session.TF_Run(session, options,
#    1020                                  feed_dict, fetch_list, target_list,
# -> 1021                                  status, run_metadata)
#    1022
#    1023     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    # TODO: Implement Function
    sentence = sentence.lower()
    vocab_to_int_keys = vocab_to_int.keys()
    word_ids = [vocab_to_int[word] if word in vocab_to_int_keys else vocab_to_int['<UNK>'] for word in sentence.split()]
    return word_ids


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-164-b448a5f5087d> in <module>()
#      10 with tf.Session(graph=loaded_graph) as sess:
#      11     # Load saved model
# ---> 12     loader = tf.train.import_meta_graph(load_path + '.meta')
#      13     loader.restore(sess, load_path)
#      14
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/training/saver.py in import_meta_graph(meta_graph_or_file, clear_devices, import_scope, **kwargs)
#    1586   """
#    1587   if not isinstance(meta_graph_or_file, meta_graph_pb2.MetaGraphDef):
# -> 1588     meta_graph_def = meta_graph.read_meta_graph_file(meta_graph_or_file)
#    1589   else:
#    1590     meta_graph_def = meta_graph_or_file
#
# /home/gus/anaconda3/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/framework/meta_graph.py in read_meta_graph_file(filename)
#     400   meta_graph_def = meta_graph_pb2.MetaGraphDef()
#     401   if not file_io.file_exists(filename):
# --> 402     raise IOError("File %s does not exist." % filename)
#     403   # First try to read it as a binary file.
#     404   file_content = file_io.FileIO(filename, "rb").read()
#
# OSError: File checkpoints/dev.meta does not exist.

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
